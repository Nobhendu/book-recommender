# %% [markdown]
# # Book recommender system

# %%
import numpy as np
import pandas as pd
import ast
import json

# %%
BX_books = pd.read_csv('./data/BX_Books.csv', sep=';', encoding='latin-1')
BX_users = pd.read_csv('./data/BX-Users.csv', sep=';', encoding='latin-1')
BX_ratings = pd.read_csv('./data/BX-Book-Ratings.csv', sep=';', encoding='latin-1')

# %%
best_books = pd.read_csv('./data/Best_Books_Ever.csv')

# %% [markdown]
# ## Recommendations based on popularity

# %%
best_books.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# ...

# %%
NUM_RATINGS = 300_000
NUM_GENRES = 10

# %%
# take necessary columns
popular_df = best_books[['title', 'author', 'rating', 'genres', 'numRatings', 'coverImg']].copy()
popular_df = popular_df.dropna().drop_duplicates(subset='title', keep='first')

# take books with atleast N ratings
popular_df = popular_df[popular_df['numRatings'] >= NUM_RATINGS]

# sort dataframe based on rating
popular_df = popular_df.sort_values(by='rating', ascending=False)

# %%
# 'author' is not well formatted, includes affiliations and irrelevant people
def clean(str):
    str = str.replace(' (Goodreads Author)', '')
    str = str.split(',')[0]
    return str
popular_df['author'] = popular_df['author'].apply(clean)

# %%
# 'genres' is a list in a string, convert to list
def clean(str):
    L = ast.literal_eval(str)
    return L
popular_df['genres'] = popular_df['genres'].apply(clean)

# %%
popular_df
# Out:
#                                        title               author  rating  \
# 342                         The Way of Kings    Brandon Sanderson    4.63
# 71      Harry Potter and the Deathly Hallows         J.K. Rowling    4.62
# 322                 A Court of Mist and Fury        Sarah J. Maas    4.62
# 709                          The Nightingale       Kristin Hannah    4.57
# 105   Harry Potter and the Half-Blood Prince         J.K. Rowling    4.57
# ...                                      ...                  ...     ...
# 100                  Moby-Dick or, the Whale      Herman Melville    3.51
# 2331                       The Nanny Diaries      Emma McLaughlin    3.43
# 169                        Heart of Darkness        Joseph Conrad    3.43
# 128                       The Scarlet Letter  Nathaniel Hawthorne    3.41
# 1255                      The Casual Vacancy         J.K. Rowling    3.30
#
#                                                  genres  numRatings  \
# ...

# %%
# get all genres in a single list
genres = popular_df[['genres']].values
genres = [item for i in genres for item in i[0]]

# get unique genres and sort
genres = np.unique(genres, return_counts=True)
genres = sorted(zip(genres[0], genres[1]), key=lambda x:x[1], reverse=True)

# get top X popular genres (X = 10)
popular_genres = genres[:NUM_GENRES]
popular_genres = [i[0] for i in popular_genres]

# %%
popular_genres
# Out:
# ['Fiction',
#  'Fantasy',
#  'Classics',
#  'Young Adult',
#  'Audiobook',
#  'Adult',
#  'Novels',
#  'Romance',
#  'Adventure',
#  'Contemporary']

# %%
# for each genre, take top T books (T = 25)
genre_wise_dfs = []

for genre in popular_genres:
    _ = popular_df[popular_df['genres'].apply(lambda x:genre in x)].iloc[:30]
    _ = _[['title', 'author', 'rating', 'coverImg']]
    # for use in JS, convert to necessary format:
    # dictionary with genre as key and list of books as value, where each book is a dictionary of reqd stuff
    genre_wise_dfs.append(_.reset_index().to_dict(orient='records'))
    # genre_wise_dfs.append(_)

popular_genre_dfs = dict((zip(popular_genres, genre_wise_dfs)))
popular_genre_dfs['genres'] = popular_genres

# %%
with open("./app/top_books.json", "w") as f:
  f.write(json.dumps(popular_genre_dfs))

# %% [markdown]
# ## Recommendations based on collaborative filtering

# %% [markdown]
# ## Recommendations based on content

# %%
best_books.head()
# Out:
#                                         bookId  \
# 0                     2767052-the-hunger-games
# 1  2.Harry_Potter_and_the_Order_of_the_Phoenix
# 2                   2657.To_Kill_a_Mockingbird
# 3                     1885.Pride_and_Prejudice
# 4                               41865.Twilight
#
#                                        title                 series  \
# 0                           The Hunger Games    The Hunger Games #1
# 1  Harry Potter and the Order of the Phoenix        Harry Potter #5
# 2                      To Kill a Mockingbird  To Kill a Mockingbird
# 3                        Pride and Prejudice                    NaN
# 4                                   Twilight   The Twilight Saga #1
#
#                                       author  rating  \
# 0                            Suzanne Collins    4.33
# 1  J.K. Rowling, Mary GrandPré (Illustrator)    4.50
# 2                                 Harper Lee    4.28
# ...

# %%
NUM_RATINGS = 50_000
NUM_RECS = 10

# %%
# filter and take necessary columns
content_df = best_books[['title', 'author', 'rating', 'description', 'language', 'genres', 'awards', 'numRatings', 'coverImg']].copy()
content_df = content_df.dropna().drop_duplicates(subset='title', keep='first')

content_df = content_df[content_df['numRatings'] >= NUM_RATINGS]
content_df = content_df[content_df['language'] == 'English']

content_df = content_df[['title', 'author', 'rating', 'description', 'genres', 'awards', 'coverImg']].copy().reset_index(drop=True)

# %%
# 'author' is not well formatted, includes affiliations and irrelevant people
def clean(str):
    str = str.replace(' (Goodreads Author)', '')
    str = str.split(',')[0]
    str = str.replace(' ', '_')
    return [str]
content_df['author'] = content_df['author'].apply(clean)

# %%
# 'genres' is a list in a string, convert to list
def clean(str):
    L = ast.literal_eval(str)
    L = [i.replace(' ', '_') for i in L]
    return L
content_df['genres'] = content_df['genres'].apply(clean)

# %%
# 'awards' is a list in a string (sometimes not), convert to list
# further, take only first award and first 3 words from that
def clean(str):
    L = ast.literal_eval(str)
    if not L:
        return []
    s = L[0]
    L = s.split()[0]
    return [L,]
content_df['awards'] = content_df['awards'].apply(clean)

# %%
# 'description' contains sentences, split each word
content_df['description'] = content_df['description'].apply(lambda x:x.split())

# %%
# the tags for recommendation include all words from genres, awards and description (buzzwords)
content_df['tags'] = content_df['genres'] + content_df['awards'] + content_df['description']

content_df['tags'] = content_df['tags'].apply(lambda x : " ".join(x).lower())

# %%
# relevant columns for recommendation and display
content_df = content_df[['title', 'author', 'rating', 'coverImg', 'tags']].copy()

# undo data processing done on authors; useful later for rendering
content_df['author'] = content_df['author'].apply(lambda x:x[0].replace("_", " "))

# %%
content_df
# Out:
#                                           title           author  rating  \
# 0                              The Hunger Games  Suzanne Collins    4.33
# 1     Harry Potter and the Order of the Phoenix     J.K. Rowling    4.50
# 2                         To Kill a Mockingbird       Harper Lee    4.28
# 3                           Pride and Prejudice      Jane Austen    4.26
# 4                                      Twilight  Stephenie Meyer    3.60
# ...                                         ...              ...     ...
# 3132                         Notorious Nineteen  Janet Evanovich    3.94
# 3133                              The Obsession     Nora Roberts    4.20
# 3134                   Good Faeries Bad Faeries      Brian Froud    3.91
# 3135           The Tea Girl of Hummingbird Lane         Lisa See    4.25
# 3136                     The Kind Worth Killing    Peter Swanson    4.03
#
#                                                coverImg  \
# ...

# %%
# stemmer (NLP technique) to resolve misunderstanding between forms of the same root word in tags
from nltk.stem.porter import PorterStemmer
ps = PorterStemmer()

# %%
def stem(text):
    L = [ps.stem(i) for i in text.split()]
    return " ".join(L)

content_df['tags'] = content_df['tags'].apply(stem)

# %%
# bag of words representation for each 'tags' string
from sklearn.feature_extraction.text import CountVectorizer
cv = CountVectorizer(max_features=5000, stop_words='english')

# %%
vectors = cv.fit_transform(content_df['tags']).toarray()

# %%
# similarity matrix between two vectors, cosine similarity metric
from sklearn.metrics.pairwise import cosine_similarity
similarity = cosine_similarity(vectors)

# %%
# final recommendation; T nearest books, excluding self (T = 10)
books = list(content_df.title.values)
content_dfs = {}

for book in content_df.title.values:
    ix = content_df[content_df['title'] == book].index[0]
    distances = similarity[ix]
    books_list = sorted(list(enumerate(distances)), key=lambda x:x[1], reverse=True)[1:NUM_RECS+1]

    recs = [rec[0] for rec in books_list]
    content_dfs[book] = [dict(content_df.iloc[i]) for i in recs]

content_dfs['books'] = books

# %%
with open("./app/content_books.json", "w") as f:
  f.write(json.dumps(content_dfs))
